# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
import numpy as np

# %%
from PIL import Image

# %%
image_obj = Image.open('source/IMG_2014.JPG')

# %%
print(image_obj.format, image_obj.size, image_obj.mode)
# Out:
# JPEG (1367, 2048) RGB

# %%
imshow(np.asarray(image_obj))

# %%
width, height = image_obj.size
image = image_obj.load()
