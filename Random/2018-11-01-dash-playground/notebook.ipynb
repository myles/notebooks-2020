# %%
from zipfile import ZipFile

# %%
zip_obj = ZipFile('source/baseballdatabank-master_2018-03-28.zip')
zip_obj.namelist()[:5]
# Out:
# ['baseballdatabank-master/',
#  'baseballdatabank-master/README.txt',
#  'baseballdatabank-master/core/',
#  'baseballdatabank-master/core/AllstarFull.csv',
#  'baseballdatabank-master/core/Appearances.csv']

# %%
with zip_obj.open('baseballdatabank-master/README.txt') as fobj:
    print(fobj.read().decode('utf-8').strip())
# Out:
# Baseball Databank is a compilation of historical baseball data in a
# convenient, tidy format, distributed under Open Data terms.
#
# This work is licensed under a Creative Commons Attribution-ShareAlike
# 3.0 Unported License.  For details see:
# http://creativecommons.org/licenses/by-sa/3.0/
#
# Organisation of the files
# -------------------------
#
# There are two directories in the repository.
#
# * 'core' contains the databank itself.  If you are a user of the data, these are the
#   files you need.
# * 'upstream' contains files used to construct the databank.
#
# Most of the data in the Databank is provided by Chadwick Baseball Bureau
# (http://www.chadwick-bureau.com).  The data differ from the data the Bureau provides
# to its clients in that it contains less detail, is updated less frequently,
# and is provided on an as-is basis.
#
#
# Other sources
# -------------
#
# The Databank is historically based in part on the Lahman Baseball Database,
# ...

# %%
zip_obj.extractall('source/')

# %%
from glob import glob

# %%
glob('source/baseballdatabank-master/core/*.csv')
# Out:
# ['source/baseballdatabank-master/core/AllstarFull.csv',
#  'source/baseballdatabank-master/core/Appearances.csv',
#  'source/baseballdatabank-master/core/AwardsManagers.csv',
#  'source/baseballdatabank-master/core/AwardsPlayers.csv',
#  'source/baseballdatabank-master/core/AwardsShareManagers.csv',
#  'source/baseballdatabank-master/core/AwardsSharePlayers.csv',
#  'source/baseballdatabank-master/core/Batting.csv',
#  'source/baseballdatabank-master/core/BattingPost.csv',
#  'source/baseballdatabank-master/core/CollegePlaying.csv',
#  'source/baseballdatabank-master/core/Fielding.csv',
#  'source/baseballdatabank-master/core/FieldingOF.csv',
#  'source/baseballdatabank-master/core/FieldingOFsplit.csv',
#  'source/baseballdatabank-master/core/FieldingPost.csv',
#  'source/baseballdatabank-master/core/HallOfFame.csv',
#  'source/baseballdatabank-master/core/HomeGames.csv',
#  'source/baseballdatabank-master/core/Managers.csv',
# ...

# %%
import pandas as pd

# %%
pd.read_csv('source/baseballdatabank-master/core/TeamsFranchises.csv').head(1)
# Out:
#   franchID             franchName active NAassoc
# 0      ALT  Altoona Mountain City      N     NaN

# %%
pd.read_csv('source/baseballdatabank-master/core/Teams.csv').head(1)
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L     ...       \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10     ...
#
#    DP     FP                  name                 park  attendance  BPF  PPF  \
# 0  24  0.834  Boston Red Stockings  South End Grounds I         NaN  103   98
#
#    teamIDBR  teamIDlahman45  teamIDretro
# 0       BOS             BS1          BS1
#
# [1 rows x 48 columns]

# %%
pd.read_csv('source/baseballdatabank-master/core/TeamsHalf.csv').head(1)
# Out:
#    yearID lgID teamID  Half divID DivWin  Rank   G   W   L
# 0    1981   NL    ATL     1     W      N     4  54  25  29
